# %%
import numpy as np
from pickle import load
from quantfreedom import FootprintCandlesTuple
from rsi_rising_falling import RSIRisingFalling

np.set_printoptions(formatter={"float_kind": "{:0.2f}".format})

# %load_ext autoreload
# %autoreload 2

# %%
with open("../dbs/oct_dec_candles.pkl", "rb") as f:
    candles: FootprintCandlesTuple = load(f)

# %%
long_strat = RSIRisingFalling(
    long_short="long",
    shuffle_bool=True,
    rsi_length=np.array([14]),
    below_rsi_cur=np.array([50]),
    below_rsi_p=np.array([50]),
    below_rsi_pp=np.array([50]),
)

set_idx = 0
long_strat.set_cur_ind_tuple(set_idx=set_idx)
long_strat.set_cur_dos_tuple(set_idx=set_idx)
long_strat.set_entries_exits_array(candles=candles)
long_strat.plot_signals(candles=candles)
